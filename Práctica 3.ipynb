# %% [markdown]
# ## Prueba de que mi pc es una mier....?

# %% [markdown]
# # Before

# %%
from IPython import display as dp

# %%
dp.Image("cores1.png")

# %%
dp.Image("cores2.png")

# %% [markdown]
# # After

# %%
def fib (n):
    if n in {0,1}:
        return 1
    else:
        return(fib(n-1)+fib(n-2))

# %%
fib(50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 fib(50)
#
# Cell In [6], line 5, in fib(n)
#       3     return 1
#       4 else:
# ----> 5     return(fib(n-1)+fib(n-2))
#
# Cell In [6], line 5, in fib(n)
#       3     return 1
#       4 else:
# ----> 5     return(fib(n-1)+fib(n-2))
#
#     [... skipping similar frames: fib at line 5 (33 times)]
#
# Cell In [6], line 5, in fib(n)
#       3     return 1
#       4 else:
# ----> 5     return(fib(n-1)+fib(n-2))
#
# Cell In [6], line 2, in fib(n)
#       1 def fib (n):
# ----> 2     if n in {0,1}:
#       3         return 1
#       4     else:
#
# KeyboardInterrupt:

# %%
dp.Image("cores3.png")

# %%
dp.Image("cores4.png")

# %%
import threading as th

# %%
import multiprocessing as mp

# %%
mp.Pool
# Out:
# <bound method BaseContext.Pool of <multiprocessing.context.DefaultContext object at 0x0000020C20C87760>>
